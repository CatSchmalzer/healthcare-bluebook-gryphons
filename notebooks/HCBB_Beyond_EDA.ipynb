# %%
import pandas as pd
import pickle
import pprint
import random

# %%
# read data in from csv
provider_no_office_by_payment_df= pd.read_csv("../data/provider_services_o_f_by_payment.csv", index_col=0)
provider_facilities_by_payment_df = pd.read_csv("../data/provider_services_f_by_payment.csv", index_col=0)
provider_offices_by_payment_df = pd.read_csv("../data/provider_services_o_by_payment.csv", index_col=0)
provider_no_office_by_revenue_df = pd.read_csv("../data/provider_services_o_f_by_revenue.csv", index_col=0)
provider_facilities_by_revenue_df = pd.read_csv("../data/provider_services_f_by_payment.csv", index_col=0)
provider_offices_by_revenue_df = pd.read_csv("../data/provider_services_o_by_payment.csv", index_col=0)

# %%
pd.options.display.max_rows = 100
provider_no_office_by_payment_df
# Out:
#                                                       0      1      2      3  \
# Vascular Surgery                                  37227  37231  37225  37229
# Urology                                           Q2043  55873  J2505  J9225
# Unknown Supplier/Provider Specialty               99291  90791  36556  92014
# Undefined Physician type                          50360  22633  63081  33533
# Thoracic Surgery                                  37227  37225  37229  33945
# Surgical Oncology                                 J2505  19296  48150  48153
# Sports Medicine                                   23472  27130  27447  27245
# Speech Language Pathologist                       92616  92612  92523  31579
# Slide Preparation Facility                        88312  88305    NaN    NaN
# Sleep Medicine                                    21080  33361  95811  95810
# Rheumatology                                      J2505  J3590  78815  J7327
# ...
