# %%
import pandas as pd
import pickle
import pprint
import random

# %%
# read data in from csv
provider_no_office_by_payment_df= pd.read_csv("../data/provider_services_o_f_by_payment.csv")
provider_facilities_by_payment_df = pd.read_csv("../data/provider_services_f_by_payment.csv")
provider_offices_by_payment_df = pd.read_csv("../data/provider_services_o_by_payment.csv")
provider_no_office_by_revenue_df = pd.read_csv("../data/provider_services_o_f_by_revenue.csv")
provider_facilities_by_revenue_df = pd.read_csv("../data/provider_services_f_by_payment.csv")
provider_offices_by_revenue_df = pd.read_csv("../data/provider_services_o_by_payment.csv")

# %%
pd.options.display.max_rows = 100
provider_no_office_by_payment_df
# Out:
#         0      1      2      3      4
# 0   37227  37231  37225  37229  37226
# 1   Q2043  55873  J2505  J9225  G0339
# 2   99291  90791  36556  92014  99239
# 3   50360  22633  63081  33533  22612
# 4   37227  37225  37229  33945  32854
# 5   J2505  19296  48150  48153  47780
# 6   23472  27130  27447  27245  29827
# 7   92616  92612  92523  31579  96125
# 8   88312  88305    NaN    NaN    NaN
# 9   21080  33361  95811  95810  21085
# 10  J2505  J3590  78815  J7327  J9310
# 11  G0108  97802  G0270  99490  97803
# 12  Q2043  22513  22514  G0339  J2505
# 13  78815  32654  36478  95811  31652
# 14  70555  96020  99350  99337  90791
# 15  27447  95811  95810  21085  95953
# 16  95811  95810  65780  78452  66821
# 17  R0070  G0202  R0075  73502  73110
# 18  36475  15738  36478  27702  27870
# 19  L8679  19364  31296  15757  20969
# 20  Q2043  L8679  J2505  J7999  37227
# 21  95913  95912  95911  95910  46930
# 22  L8679  22513  J3490  22514  36475
# 23  37227  37231  37225  37226  37229
# ...
