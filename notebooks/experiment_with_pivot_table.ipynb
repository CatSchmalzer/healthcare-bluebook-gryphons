# %%
import pandas as pd
import pickle

# %% [markdown]
# #### read csv, select rows with Entity Type 'I'

# %%
# %%time

individual_providers_rows =[]
for chunk in pd.read_csv('../data/Medicare_Provider_Utilization_and_Payment_Data__Physician_and_Other_Supplier_PUF_CY2017.csv', 
                         chunksize = 1000):
    individual_providers_rows.append(chunk[chunk['Entity Type of the Provider'] == 'I'])
    
               
                
individual_provider_type = pd.concat(individual_providers_rows, ignore_index=True)
# Out:
# Wall time: 3min 18s

# %%
individual_provider_type.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9416125 entries, 0 to 9416124
# Data columns (total 26 columns):
#  #   Column                                                    Dtype
# ---  ------                                                    -----
#  0   National Provider Identifier                              int64
#  1   Last Name/Organization Name of the Provider               object
#  2   First Name of the Provider                                object
#  3   Middle Initial of the Provider                            object
#  4   Credentials of the Provider                               object
#  5   Gender of the Provider                                    object
#  6   Entity Type of the Provider                               object
#  7   Street Address 1 of the Provider                          object
#  8   Street Address 2 of the Provider                          object
#  9   City of the Provider                                      object
#  10  Zip Code of the Provider                                  object
#  11  State Code of the Provider                                object
#  12  Country Code of the Provider                              object
#  13  Provider Type                                             object
#  14  Medicare Participation Indicator                          object
#  15  Place of Service                                          object
#  16  HCPCS Code                                                object
#  17  HCPCS Description                                         object
#  18  HCPCS Drug Indicator                                      object
#  19  Number of Services                                        float64
#  20  Number of Medicare Beneficiaries                          int64
#  21  Number of Distinct Medicare Beneficiary/Per Day Services  int64
#  22  Average Medicare Allowed Amount                           float64
#  23  Average Submitted Charge Amount                           float64
#  24  Average Medicare Payment Amount                           float64
#  25  Average Medicare Standardized Amount                      float64
# dtypes: float64(5), int64(3), object(18)
# memory usage: 1.8+ GB

# %% [markdown]
# #### select columns:
#     -

# %%
individual_provider_type_reduced = individual_provider_type[['National Provider Identifier','Entity Type of the Provider',
                                                             'Provider Type','Place of Service','HCPCS Code',
                                                             'HCPCS Description','Number of Services',
                                                             'Number of Medicare Beneficiaries',
                                                             'Number of Distinct Medicare Beneficiary/Per Day Services']]

# %%
individual_provider_type_reduced
# Out:
#          National Provider Identifier Entity Type of the Provider  \
# 0                          1003000126                           I
# 1                          1003000126                           I
# 2                          1003000126                           I
# 3                          1003000126                           I
# 4                          1003000126                           I
# ...                               ...                         ...
# 9416120                    1992999825                           I
# 9416121                    1992999874                           I
# 9416122                    1992999874                           I
# 9416123                    1992999874                           I
# 9416124                    1992999874                           I
#
#              Provider Type Place of Service HCPCS Code  \
# 0        Internal Medicine                F      99217
# 1        Internal Medicine                F      99218
# 2        Internal Medicine                F      99219
# 3        Internal Medicine                F      99220
# 4        Internal Medicine                F      99221
# ...                    ...              ...        ...
# 9416120     Otolaryngology                O      99214
# 9416121  Internal Medicine                F      99223
# 9416122  Internal Medicine                F      99232
# 9416123  Internal Medicine                F      99233
# 9416124  Internal Medicine                F      99239
#
#                                          HCPCS Description  \
# 0                      Hospital observation care discharge
# 1           Hospital observation care typically 30 minutes
# 2           Hospital observation care typically 50 minutes
# 3        Hospital observation care typically 70 minutes...
# 4        Initial hospital inpatient care, typically 30 ...
# ...                                                    ...
# 9416120  Established patient office or other outpatient...
# 9416121  Initial hospital inpatient care, typically 70 ...
# 9416122  Subsequent hospital inpatient care, typically ...
# 9416123  Subsequent hospital inpatient care, typically ...
# 9416124  Hospital discharge day management, more than 3...
#
#          Number of Services  Number of Medicare Beneficiaries  \
# 0                     100.0                                96
# 1                      26.0                                25
# 2                      52.0                                51
# 3                      59.0                                59
# 4                      16.0                                16
# ...                     ...                               ...
# 9416120               248.0                               175
# 9416121                41.0                                41
# 9416122               101.0                                57
# 9416123               102.0                                55
# 9416124                49.0                                49
#
#          Number of Distinct Medicare Beneficiary/Per Day Services
# 0                                                      100
# 1                                                       26
# 2                                                       52
# 3                                                       59
# 4                                                       16
# ...                                                    ...
# 9416120                                                248
# 9416121                                                 41
# 9416122                                                101
# 9416123                                                102
# 9416124                                                 49
#
# [9416125 rows x 9 columns]

# %%
pd.pivot_table(individual_provider_type_reduced, index = ['Provider Type', 'HCPCS Description'])
# Out:
#                                                                        National Provider Identifier  \
# Provider Type      HCPCS Description
# Addiction Medicine Administration of influenza virus vaccine                           1.518057e+09
#                    Administration of pneumococcal vaccine                              1.386659e+09
#                    Alcohol and/or substance (other than tobacco) a...                  1.124073e+09
#                    Analysis of urine                                                   1.790911e+09
#                    Annual depression screening, 15 minutes                             1.745369e+09
# ...                                                                                             ...
# Vascular Surgery   X-ray of spine of neck, 2 or 3 views                                1.578745e+09
#                    X-ray of upper arm, minimum of 2 views                              1.578745e+09
#                    X-ray of upper spine, 4 or 5 views                                  1.578745e+09
#                    X-ray of upper spine, 6 or more views                               1.578745e+09
#                    X-ray of wrist, minimum of 3 views                                  1.578745e+09
#
#                                                                        Number of Distinct Medicare Beneficiary/Per Day Services  \
# Provider Type      HCPCS Description
# Addiction Medicine Administration of influenza virus vaccine                                                       32.75
#                    Administration of pneumococcal vaccine                                                          18.50
#                    Alcohol and/or substance (other than tobacco) a...                                             817.00
#                    Analysis of urine                                                                               45.00
#                    Annual depression screening, 15 minutes                                                         69.00
# ...                                                                                                                  ...
# Vascular Surgery   X-ray of spine of neck, 2 or 3 views                                                            19.00
#                    X-ray of upper arm, minimum of 2 views                                                          14.00
#                    X-ray of upper spine, 4 or 5 views                                                              16.00
#                    X-ray of upper spine, 6 or more views                                                           16.00
#                    X-ray of wrist, minimum of 3 views                                                              25.00
#
#                                                                        Number of Medicare Beneficiaries  \
# Provider Type      HCPCS Description
# Addiction Medicine Administration of influenza virus vaccine                                      32.75
#                    Administration of pneumococcal vaccine                                         18.50
#                    Alcohol and/or substance (other than tobacco) a...                            283.00
#                    Analysis of urine                                                              12.00
#                    Annual depression screening, 15 minutes                                        69.00
# ...                                                                                                 ...
# Vascular Surgery   X-ray of spine of neck, 2 or 3 views                                           19.00
#                    X-ray of upper arm, minimum of 2 views                                         14.00
#                    X-ray of upper spine, 4 or 5 views                                             16.00
#                    X-ray of upper spine, 6 or more views                                          16.00
#                    X-ray of wrist, minimum of 3 views                                             25.00
#
#                                                                        Number of Services
# Provider Type      HCPCS Description
# Addiction Medicine Administration of influenza virus vaccine                        32.75
#                    Administration of pneumococcal vaccine                           18.50
#                    Alcohol and/or substance (other than tobacco) a...              817.00
#                    Analysis of urine                                                45.00
#                    Annual depression screening, 15 minutes                          69.00
# ...                                                                                   ...
# Vascular Surgery   X-ray of spine of neck, 2 or 3 views                             19.00
#                    X-ray of upper arm, minimum of 2 views                           14.00
#                    X-ray of upper spine, 4 or 5 views                               16.00
#                    X-ray of upper spine, 6 or more views                            16.00
#                    X-ray of wrist, minimum of 3 views                               26.00
#
# [43159 rows x 4 columns]
